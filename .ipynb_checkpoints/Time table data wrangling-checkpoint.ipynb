# %%
from tabula import read_pdf
import pandas as pd

# %%
# Select the right pages from the pdf, for me it was 4 and 5
pages = [4,5]

# %%
time_table, course_details = read_pdf(input_path="timetable.pdf",multiple_tables=True, pages=pages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-8e7465e76a7b> in <module>()
# ----> 1 time_table, course_details = read_pdf(input_path="timetable.pdf",multiple_tables=True, pages=pages)
#
# NameError: name 'pages' is not defined

# %%
time_table
# Out:
#             0         1            2              3              4        5  \
# 0         Day  Room no.  9:00 - 9:55  10:00 - 10:55  11:00 - 11:55  12:00 -
# 1         NaN       NaN          NaN            NaN            NaN    12:55
# 2      Monday    1E 303   L : AA 301     L : CE 305     L : CE 305    Lunch
# 3         NaN       NaN          NaN            NaN            NaN   Timing
# 4         NaN    1E 204   L : HS 313     L : CS 309     L : CS 305      NaN
# 5         NaN       NaN          NaN            NaN            NaN      NaN
# 6         NaN    1E 205   L : HS 323     L : EE 305    L : EE 301N      NaN
# 7         NaN    1E 304          NaN            NaN     L : ME 301      NaN
# 8         NaN    1E 305          NaN     L : MM 305     L : MM 303      NaN
# 9         NaN       NaN          NaN            NaN            NaN      NaN
# 10    Tuesday    1E 303          NaN     L : CE 307     L : CE 303    Lunch
# ...

# %%
course_details
# Out:
#                    0                                               1  \
# 0   Faculty Details:                                             NaN
# 1        Course Code                                    Course Title
# 2             AA 301                           High Energy Astronomy
# 3             CE 301                                       Hydrology
# 4             CE 303                                Soil Mechanics-I
# 5             CE 305                         Structural Mechanics-II
# 6             CE 307                          Design of Structures-I
# 7             CE 309                                         Geology
# 8             CE 353                            Soil Mechanics Lab-I
# 9             CE 357                             Design Laboratory-I
# 10            CE 359                                     Geology Lab
# 11            CE 361                     Design of Open Channel Flow
# 12            CS 303                               Operating Systems
# ...

# %%
# Out:
#          Course Code                                    Course Title  \
# 0   Faculty Details:                                             NaN
# 2             AA 301                           High Energy Astronomy
# 3             CE 301                                       Hydrology
# 4             CE 303                                Soil Mechanics-I
# 5             CE 305                         Structural Mechanics-II
# 6             CE 307                          Design of Structures-I
# 7             CE 309                                         Geology
# 8             CE 353                            Soil Mechanics Lab-I
# 9             CE 357                             Design Laboratory-I
# 10            CE 359                                     Geology Lab
# 11            CE 361                     Design of Open Channel Flow
# 12            CS 303                               Operating Systems
# 13            CS 305                           Computer Architecture
# ...

# %%
# get this from http://academic.iiti.ac.in/index1.html
courses_enrolled = ["CS 303","CS 305","CS 307","CS 309","CS 353","CS 355","CS 357","CS 359"]

# %%
rel_course = course_details[course_details[0].isin(courses_enrolled)]

# %%
rel_course
# Out:
#          0                                           1            2  \
# 12  CS 303                           Operating Systems  (2 : 1 : 0)
# 13  CS 305                       Computer Architecture  (2 : 1 : 0)
# 14  CS 307      Optimization Algorithms and Techniques  (2 : 1 : 0)
# 15  CS 309                          Parallel Computing  (2 : 1 : 0)
# 16  CS 353                       Operating Systems Lab  (0 : 0 : 3)
# 17  CS 355                   Computer Architecture Lab  (0 : 0 : 3)
# 18  CS 357  Optimization Algorithms and Techniques Lab  (0 : 0 : 3)
# 19  CS 359                      Parallel Computing Lab  (0 : 0 : 3)
#
#                        3
# 12   Dr. Gourinath Banda
# 13  Dr. Anirban Sengupta
# 14       Dr. Kapil Ahuja
# 15     Dr. Surya Prakash
# 16   Dr. Gourinath Banda
# 17  Dr. Anirban Sengupta
# 18       Dr. Kapil Ahuja
# 19     Dr. Surya Prakash

# %%
rel_course[rel_course =="CS 303"]
# Out:
# True

# %%
a = rel_course[0] =="CS 303"

# %%
b = rel_course[2].str.contains("1")

# %%
a |b
# Out:
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
b
# Out:
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# Name: 2, dtype: bool

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-51429399a6cf> in <module>()
# ----> 1 a or b
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1571         raise ValueError("The truth value of a {0} is ambiguous. "
#    1572                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1573                          .format(self.__class__.__name__))
#    1574
#    1575     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
relevant = pd.DataFrame(columns=time_table.columns)
for col in time_table.columns:
    for course in courses_enrolled:
            relevant[col] = relevant[col] | time_table[col].str.contains(course)

# %%
time_table[relevant.any(axis=1)]
# Out:
#       0       1           2           3           4       5  \
# 4   NaN  1E 204  L : HS 313  L : CS 309  L : CS 305     NaN
# 5   NaN     NaN         NaN         NaN         NaN     NaN
# 12  NaN  1E 204         NaN  L : CS 307  T : CS 309     NaN
# 13  NaN     NaN         NaN         NaN         NaN     NaN
# 21  NaN  1E 204  L : HS 313  L : CS 307  L : CS 305     NaN
# 22  NaN     NaN         NaN         NaN         NaN     NaN
# 28  NaN  1E 204         NaN  L : CS 309         NaN     NaN
# 29  NaN     NaN         NaN         NaN         NaN     NaN
# 35  NaN  1E 204  L : HS 313  T : CS 307         NaN  Timing
#
#                          6                       7    8
# 4               L : CS 303  CS1 Batch : P : CS 359  NaN
# 5                      NaN  CS2 Batch : P : CS 353  NaN
# 12  CS2 Batch : P : CS 359                     NaN  NaN
# 13  CS1 Batch : P : CS 353                     NaN  NaN
# 21              L : CS 303  CS1 Batch : P : CS 355  NaN
# ...

# %%
def gen_event(Title, day, location,  Description, startTime, endTime, addAfter):
    pass

# %%
a = f"var eventSeries = CalendarApp.getDefaultCalendar().createEventSeries(\"{Title}\",\
    new Date('January 1, 2013 03:00:00 PM EST'),\
    new Date('January 1, 2013 04:00:00 PM EST'),\
    CalendarApp.newRecurrence().addWeeklyRule()\
        .onlyOnWeekdays([CalendarApp.Weekday.{day}])\
        .until(new Date('January 1, 2014')),\
    \{location: {location}\});"
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-683b80a628d8> in <module>()
#       1 Title = "this is the title"
#       2 day = "SUNDAY"
# ----> 3 a = f"var eventSeries = CalendarApp.getDefaultCalendar().createEventSeries(\"{Title}\",    new Date('January 1, 2013 03:00:00 PM EST'),    new Date('January 1, 2013 04:00:00 PM EST'),    CalendarApp.newRecurrence().addWeeklyRule()        .onlyOnWeekdays([CalendarApp.Weekday.{day}])        .until(new Date('January 1, 2014')),    \{location: {location}\});"
#       4 print(a)
#
# NameError: name 'location' is not defined

# %%
a  = "10"

# %%
f"hello {a}"
# Out:
# 'hello 10'

# %%
import datetime

# %%
now = datetime.datetime.now()

# %%
# Out:
# time.struct_time(tm_year=2018, tm_mon=7, tm_mday=9, tm_hour=16, tm_min=44, tm_sec=23, tm_wday=0, tm_yday=190, tm_isdst=0)
